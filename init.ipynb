# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     # sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Obtaining file:///work/jupyter-swi-prolog (from -r ./requirements.txt (line 1))
# Collecting pygraphviz
#   Downloading pygraphviz-1.9.zip (119 kB)
# Collecting graphviz
#   Downloading graphviz-0.19.1-py3-none-any.whl (46 kB)
# Collecting GraphvizAnim
#   Downloading GraphvizAnim-1.1.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: ipywidgets==7.6.5 in /usr/local/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (7.6.5)
# Collecting mogrify
#   Downloading mogrify-0.1.tar.gz (3.8 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.9/site-packages (from -r ./requirements.txt (line 7)) (1.0.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: ipython>=4.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (7.31.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (5.5.5)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (4.3.3)
# Collecting pyswip
#   Downloading pyswip-0.2.10-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (1.21.4)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (0.4.5)
# Collecting decorator<5.0,>=4.0.2
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (2.26.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (0.1.9)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (2.13.3)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.9/site-packages (from moviepy->-r ./requirements.txt (line 7)) (4.62.3)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/site-packages (from imageio<3.0,>=2.5->moviepy->-r ./requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (6.1)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (3.0.28)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.17.2)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (21.4.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ./requirements.txt (line 7)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ./requirements.txt (line 7)) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ./requirements.txt (line 7)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ./requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (6.3.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (22.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (21.3.0)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (6.0.7)
# Requirement already satisfied: python-dateutil>=2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: testpath in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: bleach in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: defusedxml in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.5.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: pycparser in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (2.21)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging->bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 5)) (3.0.7)
# Building wheels for collected packages: pygraphviz, mogrify
#   Building wheel for pygraphviz (setup.py): started
#   Building wheel for pygraphviz (setup.py): finished with status 'done'
#   Created wheel for pygraphviz: filename=pygraphviz-1.9-cp39-cp39-linux_x86_64.whl size=104610 sha256=1137b57a868c4d65ea980c548fea79479f32df38870a5b5aefec1c6c14721b01
#   Stored in directory: /root/.cache/pip/wheels/db/4e/e9/f6d7ead7327fc2dc4e01c57322770a24a36e0f3a10234aa6df
#   Building wheel for mogrify (setup.py): started
#   Building wheel for mogrify (setup.py): finished with status 'done'
#   Created wheel for mogrify: filename=mogrify-0.1-py3-none-any.whl size=4431 sha256=0a69ed6db0769a219b9d4d17d037a2df6c3cfbeb18cbd87ae34ec9ae43a6f82f
#   Stored in directory: /root/.cache/pip/wheels/b9/9c/34/53ddd5607739f2369eaa5440605dc5ffb46b9d5e81a47dd5b4
# Successfully built pygraphviz mogrify
# Installing collected packages: decorator, pyswip, pygraphviz, mogrify, jswipl, GraphvizAnim, graphviz
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Not uninstalling decorator at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'decorator'. No files were found to uninstall.
#   Running setup.py develop for jswipl
# Successfully installed GraphvizAnim-1.1.0 decorator-4.4.2 graphviz-0.19.1 jswipl mogrify-0.1 pygraphviz-1.9 pyswip-0.2.10
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=32f94018-a4da-40ef-8c9f-8983d73811c8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
