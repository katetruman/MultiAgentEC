# %% [markdown]
# # AutoID

# %%
% Set up required to reset environment
?- cd('~/work'), ['dec'].
?- initialiseDEC.
?- retractall(happensAtNarrative(_,_)).
# Out:
# true.
# false.
# true.

# %% [markdown]
# https://stackoverflow.com/questions/54409923/dynamic-prolog-predicate-with-incrementing-component

# %%
% File: initiates.pl
:- dynamic nextID/1.
:- dynamic patient/2.
nextID(0).

addPatient(Sex,BDate) :-
   nextID(I),
   retract(nextID(I)),
   I1 is I+1,
   assertz(nextID(I1)),
   assertz(patient(I,Sex,BDate)).

# %%
?- addPatient('M','10-07-1965'), patient(I,Sex,BDate).
?- addPatient('F','30-12-1989'), patient(I,Sex,BDate).
# Out:
# I = 0, Sex = M, BDate = 10-07-1965 .
# I = 0, Sex = M, BDate = 10-07-1965 ;
# I = 1, Sex = F, BDate = 30-12-1989 .

# %%
?- addPatient(X,Y,Z).
# Out:
# ERROR: Caused by: '  addPatient(X,Y,Z)'. Returned: 'error(existence_error(procedure, /(addPatient, 3)), context(/(pyrun, 2), _3052))'.

# %%
?- tick(0).
?- holdsAt(F,0).
?- happensAt(E,0).
# Out:
# true.
# false.
# false.

# %%
?- tick(1).
?- holdsAt(F,1).
# Out:
# true.
# false.

# %%
?- tick(2).
?- holdsAt(F,2).
# Out:
# true.
# false.

# %%
?- initialiseDEC.
?- run(50).
?- happensAt(B,50).
?- tick(51).
?- happensAt(D,51).
# Out:
# true.
# true.
# false.
# true.
# false.

# %%
?- initialiseDEC.
?- run(150).
?- holdsAt(waiting(RID,123)=Age,150).
?- happensAt(B,150).
# Out:
# true.
# true.
# false.
# false.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1527cc64-36a2-4b35-bd8b-8d493ca554fa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
